# %%
import requests
from collections import defaultdict
from difflib import get_close_matches
import concurrent.futures

GWAS_URL = "https://www.ebi.ac.uk/gwas/rest/api/"
PVAL_THRESHOLD = 1e-2
LDLINK_TOKEN = "0cbd402f83ac"

# %%
#self.phenotype_term
def get_efo(phenotype_term):

    #search GWAS catalog for the phenotype
    search_url = f"{GWAS_URL}efoTraits/search/findByEfoTrait?trait={phenotype_term}"
    response = requests.get(search_url)
    response.raise_for_status()
    data = response.json()

    trait_map={}
    
    for trait_entry in data["_embedded"]["efoTraits"]:
        trait_name = trait_entry["trait"].lower().strip()
        efo_id = trait_entry["shortForm"]
        trait_map[trait_name] = (trait_entry["trait"], efo_id)

    candidates = list(trait_map.keys())
    best_match = get_close_matches(phenotype_term,candidates,n=1,cutoff=0.6)

    if best_match:
        matched_name = best_match[0]
        official_name, efo_id = trait_map[matched_name]

        return{
            "user_input": phenotype_term,
            "matched_trait": official_name,
            "efo_id": efo_id #self.efo_id=efo_id
        }
    else:
        return None

        


    
    #efoID -> SNPs
    #self.efo_id
def get_snp(efo_id):
    
        #Search GWAS catalog for SNPs
    search_url =f"{GWAS_URL}efoTraits/{efo_id}/associations?size=10000"
    response = requests.get(search_url)
    response.raise_for_status()
    data = response.json()
    risk_snps = []

        #Parse the response

    for assoc in data["_embedded"]["associations"]:

        pval = assoc.get("pvalue")
        odds = assoc.get("orPerCopyNum")
        raf = assoc.get("riskFrequency", "NR") #NR = not reported

        loci = assoc.get("loci",[])

        for locus in loci:

            strongest_risk_alleles = locus.get("strongestRiskAlleles", [])
            for risk_allele in strongest_risk_alleles:
                risk_allele_name = risk_allele.get("riskAlleleName")
                if risk_allele_name and "-" in risk_allele_name:
                    snp, allele = risk_allele_name.split("-")

                    risk_snps.append({
                        "snp": snp,
                        "risk_allele": allele,
                        "risk_frequency": raf,
                        "odds_ratio": odds,
                        "pvalue":pval
                    })
    high_conf_snps=[]

    for snp in risk_snps:
        if snp.get("risk_allele")!="?" and snp.get("pvalue") and snp.get("pvalue") <PVAL_THRESHOLD:
            high_conf_snps.append(snp)

    return high_conf_snps


def get_linked_variants(snp_id, pop, genome_build = "grch37", window = 500000, r2_d = "r2", threshold = 0.8, token = LDLINK_TOKEN):
        
    url = "https://ldlink.nih.gov/LDlinkRest/ldproxy"
    params = {
        "var": snp_id,
        "pop": pop,
        "r2_d": r2_d,
        "window": window,
        "genome_build": genome_build,
        "token": token
    }

    response = requests.get(url, params = params) # LDproxy returns tab-delimited text not JSON
    response.raise_for_status()
    linked_variants = []
    lines = response.text.splitlines()
    
    if len(lines)<=1:
        return linked_variants #no data

    header = lines[0].split("\t")

    for line in lines[1:]:
        fields = line.split("\t")
        if len(fields)>=10:

            if r2_d == "r2":
                if float(fields[6])>=threshold:
                    linked_variants.append({
                        "rs": fields[0],
                        "coord": fields[1],
                        "alleles": fields[2],                            
                        "maf": float(fields[3]),
                        "distance": int(fields[4]),
                        "dprime": float(fields[5]),
                        "r2": float(fields[6]),
                        "correlated_alleles": fields[7],
                        "forgedb_score": fields[8],
                        "regulomedb_score": fields[9],
                        "function": fields[10]
                    })
            else:
                if float(fields[5])>=threshold:
                    linked_variants.append({
                        "rs": fields[0],
                        "coord": fields[1],
                        "alleles": fields[2],
                        "maf": float(fields[3]),
                        "distance": int(fields[4]),
                        "dprime": float(fields[5]),
                        "r2": float(fields[6]),
                        "correlated_alleles": fields[7],
                        "forgedb_score": fields[8],
                        "regulomedb_score": fields[9],
                        "function": fields[10]
                    })   
    return linked_variants

#self.snp
def get_all_linked_variants(snp_list, population, max_workers = 10, threshold = 0.8):

    if snp_list is None:
        raise ValueError("No SNPs found. Please run get_snp() first.")

    snp_entries = snp_list
    def fetch_linked(snp_entry):
        snp_id = snp_entry["snp"]
        risk_allele = snp_entry["risk_allele"]
        original_odds_ratio = snp_entry["odds_ratio"]
            
        if not snp_id.startswith("rs"):
            return {"SNP": snp_id, "Risk_Allele": risk_allele, "odds_ratio": original_odds_ratio, "Linked SNP": []}
        try:
            linked = get_linked_variants(
                snp_id = snp_id,
                pop = population,
                genome_build = "grch37",
                r2_d = "r2",
                threshold = threshold,
                token = LDLINK_TOKEN
            )
            return {"SNP": snp_id, "Risk_Allele": risk_allele, "Linked SNP": linked}
        except Exception as e:
            print(f"Effor fetching {snp_id}:{e}")
            return {"SNP":snp_id, "Linked SNP": []}

    snp_ids = [snp["snp"] for snp in snp_list]

    results = []

    with concurrent.futures.ThreadPoolExecutor(max_workers = max_workers) as executor:
        future_to_snp = {executor.submit(fetch_linked, snp_entry):snp_entry for snp_entry in snp_entries}
        for future in concurrent.futures.as_completed(future_to_snp):
            results.append(future.result())
            
    return results

def transform_linked_snps(data):
    result = []
    for entry in data:
        risk_snp = entry.get('SNP')
        risk_allele = entry.get('Risk_Allele')
        odds_ratio = entry.get('odds_ratio')
        linked_snps = entry.get('Linked SNP', [])

        linked_result = []
        if linked_snps:
            for linked in linked_snps:
                correlated_info = linked.get('correlated_alleles', '')
                alleles = linked.get('alleles', '')
                r2_value = linked.get('r2')

                if not correlated_info or not alleles:
                    continue  # Skip if critical info missing
    
                pairs = [pair.strip() for pair in correlated_info.split(",") if "=" in pair]
                mapping = {original.strip(): linked_allele.strip() for original, linked_allele in (pair.split("=") for pair in pairs)}
    
                correlated = mapping.get(risk_allele)

                if correlated:
                        # Extract alleles properly
                    allele_list = alleles.strip('()').split('/')
                    non_correlated = [allele for allele in allele_list if allele != correlated]
                    non_correlated = non_correlated[0] if non_correlated else None

                    linked_result.append({
                        'rs': linked.get('rs'),
                        'Correlated Allele with Risk Allele': correlated,
                        'Non Correlated Allele with Risk Allele': non_correlated,
                        'r2': r2_value
                    })

        result.append({
            'SNP': risk_snp,
            'Risk_Allele': risk_allele,
            'odds_ratio': odds_ratio,
            'Linked SNP': linked_result
        })

    return result





def get_ld_snp_trait(data):

    ld_trait = {}

    for snp_entry in data:
        snp = snp_entry.get("SNP")
        original_risk_allele = snp_entry.get("Risk_Allele")
        original_odds_ratio = snp_entry.get("odds_ratio")

        ld_trait[snp]={
            "rs":snp,
            "risk_allele":original_risk_allele,
            "odds_ratio": original_odds_ratio,
            "Linked SNP":[]
        }
        
        for ld_snp in snp_entry.get("Linked SNP", []):
            rs = ld_snp.get("rs")
            corr_allele = ld_snp.get("Correlated Allele with Risk Allele")
            non_corr_allele = ld_snp.get("Non Correlated Allele with Risk Allele")
            r2 = ld_snp.get("r2")

            linked_entry = {
                "linked_rs":rs,
                "r2":r2,
                "correlated_allele":[{
                    "correlated_allele": corr_allele,
                    "trait":None,
                    "risk_frequency":None,
                    "odds_ratio": None,
                    "beta": None,
                    "beta_unit": None,
                    "beta_direction": None
                }],
                "non_correlated_allele":[{
                    "non_correlated_allele": non_corr_allele,
                    "trait":None,
                    "risk_frequency":None,
                    "odds_ratio": None,
                    "beta": None,
                    "beta_unit": None,
                    "beta_direction": None
                }]
            }

            if not rs:
                print("no rs")
                continue

        # Construct the correct URL for association lookup
            url = f"{GWAS_URL}associations/search/findByRsId?rsId={rs}"
            try:
                response = requests.get(url)
                response.raise_for_status()
                response_data = response.json()
            except Exception as e:
                print(f"Failed to retrieve associations for {rs}: {e}")
                continue

            for assoc in response_data.get("_embedded", {}).get("associations", []):
                
                pval = assoc.get("pvalue")
                odds = assoc.get("orPerCopyNum")
                beta = assoc.get("betaNum")
                beta_unit = assoc.get("betaUnit")
                beta_direction = assoc.get("betaDirection")
                raf = assoc.get("riskFrequency", "NR")
                loci = assoc.get("loci", [])

                for locus in loci:
                    for risk_allele in locus.get("strongestRiskAlleles", []):
                        risk_allele_name = risk_allele.get("riskAlleleName")
                        if risk_allele_name and "-" in risk_allele_name:
                            snp_id, allele = risk_allele_name.split("-")
                        else:
                            continue

                    # Get trait link and fetch trait data

                        
                        trait_link = assoc.get("_links", {}).get("efoTraits",{}).get("href")
                        if not trait_link:
                            continue
                        try:
                            efo_response = requests.get(trait_link)
                            efo_response.raise_for_status()
                            efo_data = efo_response.json()
                            traits = efo_data.get("_embedded", {}).get("efoTraits",[])
                        except Exception as e:
                            print(f"Failed to get traits for {rs}: {e}")
                            continue

                        for trait in traits:
                            linked_trait = trait.get("trait")

                            trait_info = {
                                    "trait": linked_trait,
                                    "risk_frequency": raf,
                                    "odds_ratio": odds,
                                    "beta": beta,
                                    "beta_unit": beta_unit,
                                    "beta_direction": beta_direction,                                        
                                    "pvalue": pval   
                            }

                            if allele == corr_allele:
                                linked_entry["correlated_allele"].append(trait_info)
                            else:
                                linked_entry["non_correlated_allele"].append(trait_info)

            ld_trait[snp]["Linked SNP"].append(linked_entry)
                                
                    
    return ld_trait

# %%
class LD:

    def __init__(self, phenotype_term, population):
        self.phenotype_term = phenotype_term.lower().strip()
        self.population = population
        self.efo_id = None
        self.matched_name = None
        self.snp = None
        self.ld_snp = None
        self.ld_snp_trait = None

    def execute(self):
        get_efo_result = get_efo(self.phenotype_term)
        self.efo_id = get_efo_result.get("efo_id")
        self.matched_name = get_efo_result.get("matched_trait")

        get_snp_result = get_snp(self.efo_id)
        self.snp = get_snp_result
        
        self.ld_snp = get_all_linked_variants(self.snp, self.population, max_workers = 10, threshold = 0.8)

        self.ld_snp = transform_linked_snps(self.ld_snp)

        self.ld_snp_trait = get_ld_snp_trait(self.ld_snp)

        return self.ld_snp_trait

# %%
preeclampsia = LD("preeclampsia", "YRI")

# %%
efo = get_efo("preeclampsia")

# %%
efo
# Out:
# {'user_input': 'preeclampsia',
#  'matched_trait': 'preeclampsia',
#  'efo_id': 'EFO_0000668'}

# %%
efo = efo.get("efo_id")

# %%
snp_result = get_snp(efo)

# %%
linked_snp = get_all_linked_variants(snp_result, "YRI", max_workers = 10, threshold = 0.8)

# %%
linked_snp = transform_linked_snps(linked_snp)

# %%
trait = get_ld_snp_trait(linked_snp)

# %%
def get_filtered(
    linked_list,
    odds_ratio_min=None,
    odds_ratio_max=None,
    with_trait=False,
    trait_filter=None,
    debug=False
):
    filtered = []

    # === 1. Filter by odds ratio thresholds ===
    for snp in linked_list:
        or_value = snp.get("odds_ratio")
        if or_value is None:
            continue
        if odds_ratio_min is not None and or_value < odds_ratio_min:
            continue
        if odds_ratio_max is not None and or_value > odds_ratio_max:
            continue
        filtered.append(snp)

    # === 2. Filter by presence of traits in correlated alleles ===
    if with_trait:
        trait_filtered = []
        for snp in filtered:
            linked_snps = snp.get("Linked SNP", [])
            new_linked_snps = []

            for linked in linked_snps:
                correlated = linked.get("correlated_allele", [])
                has_trait = [allele for allele in correlated if allele.get("trait")]

                if has_trait:
                    if debug:
                        print(f"{snp.get('rs')} -> {linked.get('linked_rs')} has traits {[a.get('trait') for a in has_trait]}")
                    linked["correlated_allele"] = has_trait
                    new_linked_snps.append(linked)

            if new_linked_snps:
                snp["Linked SNP"] = new_linked_snps
                trait_filtered.append(snp)
        filtered = trait_filtered

    # === 3. Filter by trait keyword match (e.g., 'preeclampsia') ===
    if trait_filter:
        keyword_filtered = []
        for snp in filtered:
            linked_snps = snp.get("Linked SNP", [])
            matched_snps = []

            for linked in linked_snps:
                matched_alleles = [
                    allele for allele in linked.get("correlated_allele", [])
                    if allele.get("trait") and trait_filter.lower() in allele.get("trait").lower()
                ]

                if matched_alleles:
                    if debug:
                        print(f"{snp.get('rs')} -> {linked.get('linked_rs')} MATCHES trait filter '{trait_filter}': {[a.get('trait') for a in matched_alleles]}")
                    linked["correlated_allele"] = matched_alleles
                    matched_snps.append(linked)

            if matched_snps:
                snp["Linked SNP"] = matched_snps
                keyword_filtered.append(snp)
        filtered = keyword_filtered

    return filtered

# %%
trait
# Out:
# {'chr2:167952103': {'rs': 'chr2:167952103',
#   'risk_allele': 'A',
#   'odds_ratio': 3.344,
#   'Linked SNP': []},
#  'chr2:227779489': {'rs': 'chr2:227779489',
#   'risk_allele': 'C',
#   'odds_ratio': 1.381449,
#   'Linked SNP': []},
#  'chr11:82724043': {'rs': 'chr11:82724043',
#   'risk_allele': 'G',
#   'odds_ratio': 1.458368,
#   'Linked SNP': []},
#  'rs79465287': {'rs': 'rs79465287',
#   'risk_allele': 'A',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs16998073': {'rs': 'rs16998073',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs7470773': {'rs': 'rs7470773',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs7470773',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': '0.86',
#       'odds_ratio': None,
#       'beta': 0.13,
#       'beta_unit': None,
#       'beta_direction': 'increase',
#       'pvalue': 8e-09},
#      {'trait': 'small for gestational age',
#       'risk_frequency': '0.86',
#       'odds_ratio': None,
#       'beta': 0.13,
#       'beta_unit': None,
#       'beta_direction': 'increase',
#       'pvalue': 8e-09}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs943499',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs4111084',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1072502',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1806339',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7028982',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs751619',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs573345878',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7038623',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs532537710',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10991783',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10732403',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs4743816',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs550159073',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1536516',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs180872714',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs4744032',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10115974',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10991790',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs188564391',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs547020733',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs149174087',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs569023704',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs544449743',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7044073',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7043704',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7029590',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1327356',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs5899121',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': '-',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.12,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 1e-07}]},
#    {'linked_rs': 'rs557478336',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10761107',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10761106',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs2031733',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10732402',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1887368',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7850804',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7048945',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'balding measurement',
#       'risk_frequency': '0.0810024',
#       'odds_ratio': None,
#       'beta': 0.0349505,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 7.000000000000001e-10}]},
#    {'linked_rs': 'rs7034872',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs192415926',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs541979949',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs146760217',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs182935619',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs187026994',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs559850745',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs149514617',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs559732470',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs140441193',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1835586618',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'ATATATACAC',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': '-',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'rs4909014': {'rs': 'rs4909014',
#   'risk_allele': 'C',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs4909014',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 0.695688,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-06}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs67372723',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs2396606',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs56046943',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'AA',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': '-',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7619274',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs13091893',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs6765681',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs67015567',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'CX3CL1 measurement',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': 5.7,
#       'beta_unit': 'z score',
#       'beta_direction': 'decrease',
#       'pvalue': 1e-08}]},
#    {'linked_rs': 'rs4909022',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs12637772',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs66488722',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs11129531',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7432448',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7372959',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs12486389',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs13071517',
#     'r2': 0.9122,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs13070832',
#     'r2': 0.8313,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs13059039',
#     'r2': 0.8313,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'CX3CL1 measurement',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': 5.55,
#       'beta_unit': 'z score',
#       'beta_direction': 'increase',
#       'pvalue': 3.0000000000000004e-08}]},
#    {'linked_rs': 'rs7372435',
#     'r2': 0.8313,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7374074',
#     'r2': 0.8313,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs6550150',
#     'r2': 0.8313,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'rs79300958': {'rs': 'rs79300958',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs12492798': {'rs': 'rs12492798',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs72789623': {'rs': 'rs72789623',
#   'risk_allele': 'C',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'chr1:84265767': {'rs': 'chr1:84265767',
#   'risk_allele': 'A',
#   'odds_ratio': 3.093,
#   'Linked SNP': []},
#  'rs75412999': {'rs': 'rs75412999',
#   'risk_allele': 'C',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs6545362': {'rs': 'rs6545362',
#   'risk_allele': 'A',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs6545362',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.497288,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 5e-07}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs6545361',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10186603',
#     'r2': 0.8626,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'rs180771906': {'rs': 'rs180771906',
#   'risk_allele': 'G',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'chr16:5472347': {'rs': 'chr16:5472347',
#   'risk_allele': 'C',
#   'odds_ratio': 2.210941,
#   'Linked SNP': []},
#  'rs116555978': {'rs': 'rs116555978',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs117276010': {'rs': 'rs117276010',
#   'risk_allele': 'G',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs77097613': {'rs': 'rs77097613',
#   'risk_allele': 'A',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs4899946': {'rs': 'rs4899946',
#   'risk_allele': 'C',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs4899946',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.869197,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 9e-06}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs74940643',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs78018506',
#     'r2': 0.8103,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'chr13:111408864': {'rs': 'chr13:111408864',
#   'risk_allele': 'C',
#   'odds_ratio': 3.114205,
#   'Linked SNP': []},
#  'rs58672332': {'rs': 'rs58672332',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs58672332',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.517343,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 1e-06}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs12244105',
#     'r2': 0.9812,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10826872',
#     'r2': 0.9627,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1340951',
#     'r2': 0.9625,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs57822625',
#     'r2': 0.9625,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'carpal tunnel syndrome',
#       'risk_frequency': '0.132',
#       'odds_ratio': 1.0662,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 3e-10}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs1538955',
#     'r2': 0.9438,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs55788737',
#     'r2': 0.8896,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs6481721',
#     'r2': 0.84,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs6481719',
#     'r2': 0.84,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs148360740',
#     'r2': 0.84,
#     'correlated_allele': [{'correlated_allele': 'ATT',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': '-',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7092801',
#     'r2': 0.84,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7076517',
#     'r2': 0.84,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7092646',
#     'r2': 0.84,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7092641',
#     'r2': 0.84,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs12774516',
#     'r2': 0.8235,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'rs12460911': {'rs': 'rs12460911',
#   'risk_allele': 'A',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs12460911',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.564896,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 1e-06}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'rs11210485': {'rs': 'rs11210485',
#   'risk_allele': 'A',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs11210485',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.575096,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 3e-06}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
# ...
#       'risk_frequency': '0.42',
#       'odds_ratio': 1.09,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-10},
#      {'trait': 'hypertension, pregnancy-induced',
#       'risk_frequency': '0.42',
#       'odds_ratio': 1.09,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-10},
#      {'trait': 'handedness',
#       'risk_frequency': '0.4672',
#       'odds_ratio': 0.9693829,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 5.999999999999999e-21}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'neuroimaging measurement',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-18},
#      {'trait': 'healthspan',
#       'risk_frequency': '0.53',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-09},
#      {'trait': 'life span trait',
#       'risk_frequency': '0.53',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-09},
#      {'trait': 'parental longevity',
#       'risk_frequency': '0.53',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-09},
#      {'trait': 'parental longevity',
#       'risk_frequency': '0.52',
#       'odds_ratio': None,
#       'beta': 0.2507,
#       'beta_unit': 'years',
#       'beta_direction': 'increase',
#       'pvalue': 1e-10},
#      {'trait': 'respiratory system disease',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 8e-09},
#      {'trait': 'balding measurement',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 4.9999999999999995e-11}]},
#    {'linked_rs': 'rs8039305',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'neutrophil count',
#       'risk_frequency': '0.476039',
#       'odds_ratio': None,
#       'beta': 0.017378971,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 6.0000000000000005e-15},
#      {'trait': 'HMG CoA reductase inhibitor use measurement',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': 0.0307,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 4e-09},
#      {'trait': 'serum alanine aminotransferase measurement',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': 0.0026,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 2e-11}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'apolipoprotein a 1 measurement',
#       'risk_frequency': '0.524054',
#       'odds_ratio': None,
#       'beta': 0.0127294,
#       'beta_unit': 'unit',
#       'beta_direction': 'decrease',
#       'pvalue': 1e-10},
#      {'trait': 'major depressive disorder',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-08},
#      {'trait': 'schizophrenia',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 4.9999999999999995e-11},
#      {'trait': 'bipolar disorder',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 3.0000000000000004e-09},
#      {'trait': 'neutrophil count',
#       'risk_frequency': '0.524',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 9.000000000000001e-09},
#      {'trait': 'hypertension',
#       'risk_frequency': '0.857',
#       'odds_ratio': None,
#       'beta': 0.0948,
#       'beta_unit': 'unit',
#       'beta_direction': 'decrease',
#       'pvalue': 7.000000000000001e-09}]},
#    {'linked_rs': 'rs11372849',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': '-',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'coronary artery disease',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-18},
#      {'trait': 'opioid use disorder',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': 6.12,
#       'beta_unit': 'Z score',
#       'beta_direction': 'increase',
#       'pvalue': 1e-09}]},
#    {'linked_rs': 'rs17514846',
#     'r2': 0.8387,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'coronary artery disease',
#       'risk_frequency': '0.4605',
#       'odds_ratio': None,
#       'beta': 0.0559,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 1e-26},
#      {'trait': 'systolic blood pressure',
#       'risk_frequency': '0.1441',
#       'odds_ratio': None,
#       'beta': 0.5307,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 5e-09},
#      {'trait': 'smoking initiation',
#       'risk_frequency': '0.437',
#       'odds_ratio': None,
#       'beta': 0.00605,
#       'beta_unit': 'unit',
#       'beta_direction': 'decrease',
#       'pvalue': 1e-14},
#      {'trait': 'coronary artery disease',
#       'risk_frequency': '0.4577',
#       'odds_ratio': None,
#       'beta': 0.0613,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 8e-27},
#      {'trait': 'mean arterial pressure',
#       'risk_frequency': '0.1441',
#       'odds_ratio': None,
#       'beta': 0.3956,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 2e-07},
#      {'trait': 'coronary artery disease',
#       'risk_frequency': '0.440264',
#       'odds_ratio': 1.05,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 3e-07},
#      {'trait': 'smoking initiation',
#       'risk_frequency': '0.461',
#       'odds_ratio': None,
#       'beta': 0.00697,
#       'beta_unit': 'unit',
#       'beta_direction': 'decrease',
#       'pvalue': 3.0000000000000002e-15},
#      {'trait': 'hypertension',
#       'risk_frequency': '0.1441',
#       'odds_ratio': None,
#       'beta': 0.1125,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 3.0000000000000004e-09},
#      {'trait': 'attempted suicide',
#       'risk_frequency': '0.49',
#       'odds_ratio': 0.954,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 2e-09}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'schizophrenia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.076,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 6e-11},
#      {'trait': 'parental longevity',
#       'risk_frequency': '0.53',
#       'odds_ratio': None,
#       'beta': 0.0139,
#       'beta_unit': 'unit',
#       'beta_direction': 'decrease',
#       'pvalue': 7.000000000000001e-10},
#      {'trait': 'parental longevity',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 7e-07},
#      {'trait': 'opioid use disorder',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': 5.59,
#       'beta_unit': 'Z score',
#       'beta_direction': 'decrease',
#       'pvalue': 2e-08},
#      {'trait': 'mean arterial pressure',
#       'risk_frequency': '0.488107379015702',
#       'odds_ratio': None,
#       'beta': 0.32957354,
#       'beta_unit': 'unit',
#       'beta_direction': 'decrease',
#       'pvalue': 2e-10},
#      {'trait': 'parental longevity',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 1e-07},
#      {'trait': 'systolic blood pressure',
#       'risk_frequency': 'NR',
#       'odds_ratio': None,
#       'beta': 0.02987,
#       'beta_unit': 'unit',
#       'beta_direction': 'increase',
#       'pvalue': 3.0000000000000004e-08},
#      {'trait': 'schizophrenia',
#       'risk_frequency': 'NR',
#       'odds_ratio': 1.0706638,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 3e-12}]}]},
#  'rs13306561': {'rs': 'rs13306561',
#   'risk_allele': 'G',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs1918969': {'rs': 'rs1918969',
#   'risk_allele': 'C',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs75293382': {'rs': 'rs75293382',
#   'risk_allele': 'C',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs75293382',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': '0.06',
#       'odds_ratio': 1.3,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 1e-06},
#      {'trait': 'fetal genotype effect measurement',
#       'risk_frequency': '0.06',
#       'odds_ratio': 1.3,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 1e-06}],
#     'non_correlated_allele': [{'non_correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'rs117928258': {'rs': 'rs117928258',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs10843404': {'rs': 'rs10843404',
#   'risk_allele': 'C',
#   'odds_ratio': None,
#   'Linked SNP': [{'linked_rs': 'rs10843404',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None},
#      {'trait': 'preeclampsia',
#       'risk_frequency': '0.47',
#       'odds_ratio': 1.08,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 3.0000000000000004e-08},
#      {'trait': 'hypertension, pregnancy-induced',
#       'risk_frequency': '0.47',
#       'odds_ratio': 1.08,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None,
#       'pvalue': 3.0000000000000004e-08}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs7957287',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10843408',
#     'r2': 1.0,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs4271436',
#     'r2': 0.9815,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs11050218',
#     'r2': 0.9815,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10843400',
#     'r2': 0.9455,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10743660',
#     'r2': 0.8445,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10743661',
#     'r2': 0.8445,
#     'correlated_allele': [{'correlated_allele': 'T',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'C',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]},
#    {'linked_rs': 'rs10771523',
#     'r2': 0.8129,
#     'correlated_allele': [{'correlated_allele': 'A',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}],
#     'non_correlated_allele': [{'non_correlated_allele': 'G',
#       'trait': None,
#       'risk_frequency': None,
#       'odds_ratio': None,
#       'beta': None,
#       'beta_unit': None,
#       'beta_direction': None}]}]},
#  'rs979971': {'rs': 'rs979971',
#   'risk_allele': 'T',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs201454025': {'rs': 'rs201454025',
#   'risk_allele': 'G',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs13176432': {'rs': 'rs13176432',
#   'risk_allele': 'G',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs13210237': {'rs': 'rs13210237',
#   'risk_allele': 'A',
#   'odds_ratio': None,
#   'Linked SNP': []},
#  'rs113935429': {'rs': 'rs113935429',
#   'risk_allele': 'A',
#   'odds_ratio': None,
#   'Linked SNP': []}}

# %%
filtered_snps = get_filtered(list(trait.values()), with_trait=True)

# %%
any_trait = [
    snp for snp in list(trait.values())
    if any(
        any(c.get("trait") for c in l.get("correlated_allele", []))
        for l in snp.get("Linked SNP", [])
    )
]
print(len(any_trait))
# Out:
# 14

# %%
filtered_snps
# Out:
# []
